# %%
print("Bem-vindo ao sistema de cadastro da Academia START STRONG!") # Mensagem de boas-vindas

Nome = input("Por favor, digite o seu nome completo: ") # Solicita o nome do usuário  # exemplo de apenas texto
CPF = int ("Por favor, digite o seu cpf: ") # Solicita o CPF do usuário  # exemplo de números inteiros
Idade = int ("Por favor, digite a sua idade: ") # Solicita a idade do usuário  # exemplo de apenas texto
Peso = float ("Por favor, informe o seu peso (kg): ") # Solicita o peso do usuário  # exemplo de apenas números float
Altura = float ("Por favor, informe a sua altura (m): ") # Solicita a altura do usuário  # exemplo de apenas números float
Objetivo = input ("Por favor, informe o objetivo do treino: ") # Solicita a informação do objetivo do treino do usuário  # exemplo de apenas texto

print("\ncadastro realizado com sucesso!")
print("Nome:", Nome)
print("CPF:", CPF)
print("Idade:", Idade)
print("Peso:", Peso)
print("Altura:", Altura)
print("Objetivo:", Objetivo)
# Out:
# Bem-vindo ao sistema de cadastro da Academia START STRONG!
